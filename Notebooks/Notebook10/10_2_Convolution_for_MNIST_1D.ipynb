# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to c:\users\nesto\appdata\local\temp\pip-req-build-yqvizg7c
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (3.10.1)
# Requirement already satisfied: scipy in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from mnist1d==0.0.2.post16) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nesto\appdata\local\programs\python\python313\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\nesto\AppData\Local\Temp\pip-req-build-yqvizg7c'
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(

nn.Conv1d(in_channels= 1, kernel_size= 3, stride= 2, padding="valid", out_channels= 15),
nn.ReLU(),
nn.Conv1d(in_channels= 15, kernel_size= 3, stride= 2, padding="valid", out_channels= 15),
nn.ReLU(),
nn.Conv1d(in_channels= 15, kernel_size= 3, stride= 2, padding="valid", out_channels= 15),
nn.ReLU(),
nn.Flatten(),
nn.Linear(60, D_o)

)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.948908, train error 75.80,  val loss 1.969459, percent error 77.50
# Epoch     1, train loss 1.438186, train error 57.45,  val loss 1.460055, percent error 62.10
# Epoch     2, train loss 1.372078, train error 55.12,  val loss 1.366507, percent error 57.10
# Epoch     3, train loss 1.273178, train error 51.78,  val loss 1.283378, percent error 54.40
# Epoch     4, train loss 1.195934, train error 47.33,  val loss 1.210830, percent error 49.70
# Epoch     5, train loss 1.131254, train error 43.55,  val loss 1.148322, percent error 44.70
# Epoch     6, train loss 0.959350, train error 38.35,  val loss 1.000630, percent error 42.50
# Epoch     7, train loss 0.862570, train error 35.18,  val loss 0.906983, percent error 37.00
# Epoch     8, train loss 0.788946, train error 31.47,  val loss 0.850624, percent error 34.70
# Epoch     9, train loss 0.665942, train error 26.68,  val loss 0.737558, percent error 29.60
# Epoch    10, train loss 0.642866, train error 25.68,  val loss 0.699930, percent error 27.90
# Epoch    11, train loss 0.597748, train error 23.57,  val loss 0.671070, percent error 26.20
# Epoch    12, train loss 0.500884, train error 18.82,  val loss 0.575724, percent error 21.40
# Epoch    13, train loss 0.466521, train error 18.07,  val loss 0.544474, percent error 19.10
# Epoch    14, train loss 0.436842, train error 16.22,  val loss 0.559178, percent error 21.50
# Epoch    15, train loss 0.353567, train error 13.60,  val loss 0.466927, percent error 18.00
# Epoch    16, train loss 0.375802, train error 14.38,  val loss 0.528354, percent error 19.30
# Epoch    17, train loss 0.357957, train error 13.80,  val loss 0.524790, percent error 19.20
# Epoch    18, train loss 0.259947, train error 9.32,  val loss 0.415495, percent error 14.90
# Epoch    19, train loss 0.232515, train error 8.38,  val loss 0.406177, percent error 13.80
# Epoch    20, train loss 0.184425, train error 6.82,  val loss 0.370622, percent error 12.10
# Epoch    21, train loss 0.194391, train error 7.72,  val loss 0.364445, percent error 13.10
# Epoch    22, train loss 0.188722, train error 6.72,  val loss 0.376806, percent error 12.90
# Epoch    23, train loss 0.150026, train error 5.55,  val loss 0.342742, percent error 11.60
# Epoch    24, train loss 0.148831, train error 5.53,  val loss 0.358178, percent error 11.80
# Epoch    25, train loss 0.135662, train error 4.85,  val loss 0.338450, percent error 11.50
# Epoch    26, train loss 0.120312, train error 3.95,  val loss 0.325992, percent error 10.90
# Epoch    27, train loss 0.125262, train error 4.32,  val loss 0.346082, percent error 11.30
# Epoch    28, train loss 0.125973, train error 4.32,  val loss 0.338659, percent error 11.10
# Epoch    29, train loss 0.109090, train error 3.60,  val loss 0.335133, percent error 10.10
# Epoch    30, train loss 0.109314, train error 3.65,  val loss 0.345945, percent error 10.30
# Epoch    31, train loss 0.112932, train error 3.97,  val loss 0.348373, percent error 11.40
# Epoch    32, train loss 0.090347, train error 2.85,  val loss 0.345776, percent error 11.30
# Epoch    33, train loss 0.083094, train error 2.62,  val loss 0.336947, percent error 10.60
# Epoch    34, train loss 0.102531, train error 3.65,  val loss 0.358624, percent error 11.00
# Epoch    35, train loss 0.084241, train error 3.03,  val loss 0.323682, percent error 10.00
# Epoch    36, train loss 0.098797, train error 3.40,  val loss 0.395236, percent error 11.20
# Epoch    37, train loss 0.074889, train error 2.60,  val loss 0.337661, percent error 11.60
# Epoch    38, train loss 0.077859, train error 2.75,  val loss 0.344306, percent error 9.70
# Epoch    39, train loss 0.070816, train error 2.25,  val loss 0.361072, percent error 10.00
# Epoch    40, train loss 0.050932, train error 1.40,  val loss 0.320657, percent error 9.30
# Epoch    41, train loss 0.054416, train error 1.55,  val loss 0.344608, percent error 9.80
# Epoch    42, train loss 0.047289, train error 1.03,  val loss 0.334389, percent error 9.70
# Epoch    43, train loss 0.046256, train error 1.10,  val loss 0.339100, percent error 10.00
# Epoch    44, train loss 0.046660, train error 1.15,  val loss 0.341908, percent error 9.40
# Epoch    45, train loss 0.046376, train error 0.97,  val loss 0.343011, percent error 9.80
# Epoch    46, train loss 0.044533, train error 0.95,  val loss 0.348650, percent error 9.60
# Epoch    47, train loss 0.043393, train error 0.93,  val loss 0.355120, percent error 9.70
# Epoch    48, train loss 0.046398, train error 1.22,  val loss 0.353989, percent error 9.20
# Epoch    49, train loss 0.039795, train error 0.85,  val loss 0.348364, percent error 9.20
# Epoch    50, train loss 0.040336, train error 0.95,  val loss 0.367396, percent error 9.40
# Epoch    51, train loss 0.038337, train error 0.90,  val loss 0.351621, percent error 9.60
# Epoch    52, train loss 0.038086, train error 0.82,  val loss 0.353260, percent error 8.90
# Epoch    53, train loss 0.041972, train error 1.05,  val loss 0.362949, percent error 9.60
# Epoch    54, train loss 0.036584, train error 0.70,  val loss 0.359224, percent error 9.80
# Epoch    55, train loss 0.035112, train error 0.62,  val loss 0.355718, percent error 9.60
# Epoch    56, train loss 0.038463, train error 0.97,  val loss 0.378008, percent error 9.80
# Epoch    57, train loss 0.040073, train error 1.07,  val loss 0.391675, percent error 10.00
# Epoch    58, train loss 0.033194, train error 0.78,  val loss 0.376892, percent error 9.50
# Epoch    59, train loss 0.031536, train error 0.70,  val loss 0.373727, percent error 9.60
# Epoch    60, train loss 0.028936, train error 0.43,  val loss 0.364982, percent error 9.30
# Epoch    61, train loss 0.028621, train error 0.43,  val loss 0.373627, percent error 9.20
# Epoch    62, train loss 0.028263, train error 0.50,  val loss 0.375975, percent error 9.00
# Epoch    63, train loss 0.027854, train error 0.30,  val loss 0.367538, percent error 9.30
# Epoch    64, train loss 0.027923, train error 0.50,  val loss 0.372541, percent error 9.20
# Epoch    65, train loss 0.027377, train error 0.38,  val loss 0.381066, percent error 9.60
# Epoch    66, train loss 0.026725, train error 0.35,  val loss 0.377819, percent error 9.20
# Epoch    67, train loss 0.026059, train error 0.38,  val loss 0.378403, percent error 9.00
# Epoch    68, train loss 0.026498, train error 0.38,  val loss 0.377268, percent error 9.30
# Epoch    69, train loss 0.026535, train error 0.32,  val loss 0.383231, percent error 9.40
# Epoch    70, train loss 0.025384, train error 0.30,  val loss 0.383915, percent error 9.50
# Epoch    71, train loss 0.024738, train error 0.28,  val loss 0.381636, percent error 9.40
# Epoch    72, train loss 0.026395, train error 0.35,  val loss 0.382536, percent error 9.10
# Epoch    73, train loss 0.024417, train error 0.28,  val loss 0.381990, percent error 9.40
# Epoch    74, train loss 0.024027, train error 0.20,  val loss 0.383831, percent error 9.60
# Epoch    75, train loss 0.023764, train error 0.28,  val loss 0.388723, percent error 9.40
# Epoch    76, train loss 0.024495, train error 0.30,  val loss 0.393214, percent error 9.30
# Epoch    77, train loss 0.023508, train error 0.25,  val loss 0.384293, percent error 9.30
# Epoch    78, train loss 0.023573, train error 0.25,  val loss 0.381368, percent error 9.30
# Epoch    79, train loss 0.023421, train error 0.18,  val loss 0.385966, percent error 9.40
# Epoch    80, train loss 0.022484, train error 0.25,  val loss 0.390415, percent error 9.00
# Epoch    81, train loss 0.022167, train error 0.20,  val loss 0.390250, percent error 9.20
# Epoch    82, train loss 0.022985, train error 0.30,  val loss 0.397026, percent error 9.50
# Epoch    83, train loss 0.022156, train error 0.25,  val loss 0.392142, percent error 9.50
# Epoch    84, train loss 0.021943, train error 0.22,  val loss 0.399362, percent error 9.50
# Epoch    85, train loss 0.022383, train error 0.20,  val loss 0.394851, percent error 9.20
# Epoch    86, train loss 0.021567, train error 0.25,  val loss 0.395834, percent error 9.20
# Epoch    87, train loss 0.021620, train error 0.20,  val loss 0.391369, percent error 9.30
# Epoch    88, train loss 0.021432, train error 0.18,  val loss 0.399131, percent error 9.40
# Epoch    89, train loss 0.021604, train error 0.22,  val loss 0.394565, percent error 9.00
# Epoch    90, train loss 0.021365, train error 0.18,  val loss 0.396402, percent error 9.40
# Epoch    91, train loss 0.021077, train error 0.18,  val loss 0.395602, percent error 9.30
# Epoch    92, train loss 0.021002, train error 0.22,  val loss 0.400591, percent error 9.30
# Epoch    93, train loss 0.020884, train error 0.20,  val loss 0.401075, percent error 9.10
# Epoch    94, train loss 0.020658, train error 0.18,  val loss 0.400051, percent error 9.30
# Epoch    95, train loss 0.020642, train error 0.20,  val loss 0.402973, percent error 9.20
# Epoch    96, train loss 0.020420, train error 0.15,  val loss 0.399459, percent error 9.20
# Epoch    97, train loss 0.020362, train error 0.18,  val loss 0.403368, percent error 9.30
# Epoch    98, train loss 0.020315, train error 0.20,  val loss 0.406054, percent error 9.40
# Epoch    99, train loss 0.020113, train error 0.20,  val loss 0.402298, percent error 9.30
